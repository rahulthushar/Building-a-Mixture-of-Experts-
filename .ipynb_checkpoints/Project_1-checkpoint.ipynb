# %%
import os 
import nltk

# %%
# !pip install transformers torch streamlit
# Out:
# Requirement already satisfied: transformers in /Users/rahul/genai/lib/python3.13/site-packages (5.0.0)
# Requirement already satisfied: torch in /Users/rahul/genai/lib/python3.13/site-packages (2.10.0)
# Requirement already satisfied: streamlit in /Users/rahul/genai/lib/python3.13/site-packages (1.53.1)
# Requirement already satisfied: filelock in /Users/rahul/genai/lib/python3.13/site-packages (from transformers) (3.20.3)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /Users/rahul/genai/lib/python3.13/site-packages (from transformers) (1.3.4)
# Requirement already satisfied: numpy>=1.17 in /Users/rahul/genai/lib/python3.13/site-packages (from transformers) (2.4.1)
# Requirement already satisfied: packaging>=20.0 in /Users/rahul/genai/lib/python3.13/site-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/rahul/genai/lib/python3.13/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/rahul/genai/lib/python3.13/site-packages (from transformers) (2026.1.15)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/rahul/genai/lib/python3.13/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /Users/rahul/genai/lib/python3.13/site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/rahul/genai/lib/python3.13/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /Users/rahul/genai/lib/python3.13/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/rahul/genai/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /Users/rahul/genai/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/rahul/genai/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: shellingham in /Users/rahul/genai/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/rahul/genai/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in /Users/rahul/genai/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /Users/rahul/genai/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/rahul/genai/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /Users/rahul/genai/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/rahul/genai/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: setuptools in /Users/rahul/genai/lib/python3.13/site-packages (from torch) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /Users/rahul/genai/lib/python3.13/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/rahul/genai/lib/python3.13/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/rahul/genai/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /Users/rahul/genai/lib/python3.13/site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /Users/rahul/genai/lib/python3.13/site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=5.5 in /Users/rahul/genai/lib/python3.13/site-packages (from streamlit) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in /Users/rahul/genai/lib/python3.13/site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: pandas<3,>=1.4.0 in /Users/rahul/genai/lib/python3.13/site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in /Users/rahul/genai/lib/python3.13/site-packages (from streamlit) (12.1.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /Users/rahul/genai/lib/python3.13/site-packages (from streamlit) (6.33.4)
# Requirement already satisfied: pyarrow>=7.0 in /Users/rahul/genai/lib/python3.13/site-packages (from streamlit) (23.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /Users/rahul/genai/lib/python3.13/site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /Users/rahul/genai/lib/python3.13/site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/rahul/genai/lib/python3.13/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/rahul/genai/lib/python3.13/site-packages (from streamlit) (3.1.46)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Users/rahul/genai/lib/python3.13/site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /Users/rahul/genai/lib/python3.13/site-packages (from streamlit) (6.5.4)
# Requirement already satisfied: jsonschema>=3.0 in /Users/rahul/genai/lib/python3.13/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.27.1 in /Users/rahul/genai/lib/python3.13/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.15.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/rahul/genai/lib/python3.13/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/rahul/genai/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/rahul/genai/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/rahul/genai/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/rahul/genai/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/rahul/genai/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rahul/genai/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (2.6.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/rahul/genai/lib/python3.13/site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/rahul/genai/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/rahul/genai/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/rahul/genai/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/rahul/genai/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in /Users/rahul/genai/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/rahul/genai/lib/python3.13/site-packages (from sympy>=1.13.3->torch) (1.3.0)

# %% [markdown]
# ### Project Idea News article summariser ###
# **Working**
# - User uploads the text directly to terminal or can also upload it through a text file
# - Then the text is processed through 'distilbart' for summarization
# - Model generates a 200-300 word summary of the given article

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import sys

# ----------------------------
# Load model & tokenizer
# ----------------------------
MODEL_NAME = "sshleifer/distilbart-cnn-12-6"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForSeq2SeqLM.from_pretrained(MODEL_NAME)

# ----------------------------
# Summarization function
# ----------------------------
def summarize_article(article_text, max_len=300, min_len=200):
    inputs = tokenizer(
        article_text,
        return_tensors="pt",
        truncation=True,
        max_length=1024
    )

    summary_ids = model.generate(
        inputs["input_ids"],
        max_length=max_len,
        min_length=min_len,
        do_sample=False
    )

    return tokenizer.decode(summary_ids[0], skip_special_tokens=True)

# ----------------------------
# Input handler function
# ----------------------------
def get_article_from_user():
    print("\nChoose input method:")
    print("1. Paste article in terminal")
    print("2. Load article from text file")

    choice = input("\nEnter choice (1/2): ").strip()

    if choice == "1":
        print("\nPaste your article below.")
        print("Press ENTER on an empty line to finish:\n")

        lines = []
        while True:
            line = input()
            if line.strip() == "":
                break
            lines.append(line)

        return "\n".join(lines)

    elif choice == "2":
        file_path = input("\nEnter path to text file: ").strip()
        try:
            with open(file_path, "r", encoding="utf-8") as f:
                return f.read()
        except Exception as e:
            print("❌ Error reading file:", e)
            exit(1)

    else:
        print("❌ Invalid choice")
        exit(1)

# ----------------------------
# Main execution
# ----------------------------
if __name__ == "__main__":
    article_text = get_article_from_user()
    summary = summarize_article(article_text)

    print("\n" + "="*40)
    print("SUMMARY")
    print("="*40)
    print(summary)
# Out:
# Loading weights: 100%|█| 358/358 [00:00<00:00, 1345.35it/s, Materializing param=
# The tied weights mapping and config for this model specifies to tie model.shared.weight to model.decoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie model.shared.weight to model.encoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Choose input method:
# 1. Paste article in terminal
# 2. Load article from text file
# Enter choice (1/2):  1
# Paste your article below.
# Press ENTER on an empty line to finish:
#  New Delhi: The government will present facts to counter 'misinformation' being spread by the opposition over the University Grants Commission's new rules – the Equity in Higher Education Institutions Regulation, meant to prevent caste-based discrimination on campus – top sources told NDTV Tuesday.  Sources also said misuse of the rules 'will not be allowed, under any circumstances'.  The government is likely to clarify its position on the UGC's new rules, which came into effect on January 13 and which, reports indicate, have upset the so-called upper caste.  Sources also told NDTV the opposition is trying to 'escalate the issue', which now includes the resignation of the City Magistrate from Uttar Pradesh's Bareilly and that of a leader from the ruling BJP's youth wing, the Yuva Morcha, before Parliament's Budget session begins next week.  Both the district official, Alankar Agnihotri, and the BJP leader (as yet unnamed), warned the new rules will spread division rather than engender reform. Agnihotri called them a "black law", said they would spoil the academic environment, and should be withdrawn immediately.  READ | Bareilly City Magistrate Resigns Over New UGC Policies  Tension over the rules ratcheted up after Union Minister of State for Home, Nityanand Rai, came under fire for publicly avoiding questions on the subject. Media reports said Rai, who was at an event in Bihar, simply began chanting 'Har Har, Mahadev' when reporters asked questions.  The Union Education Minister has also avoided giving a direct response; he would only say the government is open to discussions on the topic and that the rules are meant to promote equity.  What are the new UGC rules?  The University Grants Commission (Promotion of Equity in Higher Education Institutions) Regulations, 2026, prescribe a structured framework for grievance redressal, inclusion, and support for disadvantaged groups across universities and colleges.  NDTV Explains | New Equity Regulations For Higher Education Institutions  The regulations follow directions from the Supreme Court, which had asked the UGC to submit updated rules while hearing a petition – filed by the mothers of Rohith Vemula and Payal Tadvi –related to the implementation of the 2012 UGC anti-discrimination regulations.  Vemula, a PhD scholar at the University of Hyderabad, died by suicide in 2016, allegedly after facing caste-based harassment. In 2019, Tadvi, a resident doctor at Mumbai's Topiwala National Medical College and BYL Nair Hospital, also died by suicide, with allegations of casteist harassment by seniors.  The new framework aims to put in place institutional mechanisms to prevent discrimination and ensure timely redressal within higher education campuses.  What do critics say?  However, critics have warned that under this new rule, students of the general category have been labelled as 'criminals'. Agnihotri, for example, alleged they could lead to atrocities against Brahmins.  The provisions were discriminatory and could lead to social unrest, he said.  The main issue, reports indicate, revolve around three points. These are:  No complaint mechanism for general category – The new rules call out "caste-based discrimination" as against those from SC/ST/OBC only. Critics claim this excludes general category students as they cannot file complaints under this wording.  False complaint penalties – There was a provision in an earlier draft that has now been dropped. This means complainants (i.e., those from reserved categories) get protection but critics argue there are no deterrents (fines, for example) for false claims. This, they have argued, risks 'guilt by assumption' for upper castes.  'Biased' committees – The anti-harassment cells to be set up under the rules must include representatives from the SC/ST/OBC groups and women. Critics, though, say it should also include reps from general category, declaring this speaks of a bias against this group.  Political row builds  Meanwhile, UP Congr ...
# ========================================
# SUMMARY
# ========================================
#  The government is likely to clarify its position on the UGC's new rules, which came into effect on January 13 . The opposition is trying to 'escalate the issue', which now includes the resignation of the Bareilly City Magistrate from Uttar Pradesh's Bareilly and that of a leader from the ruling BJP's youth wing, the Yuva Morcha . Tension over the rules ratcheted up after Union Minister of State for State for Home, Nityanand Rai, came under fire for avoiding questions on the issue . The new rules call out 'caste-based discrimination" as against those from SC/ST/OBC only . Critics claim this excludes general category students as they cannot file complaints under this wording . There was a provision in an earlier draft that has now been dropped. Critics argue there are no deterrents (fines, for example, for . example) for false claims. This, they have argued, risks 'guilt by assumption' for upper castes.

# %% [markdown]
# ## Project: News Article TL;DR Generator
#
# **Category:** Text Summarization (Productivity Use Case)
#
# **Objective:**
# Automatically convert long news articles into a short eight to ten-sentence summary.
#
# **Methodology:**
# A pretrained abstractive summarization model is applied to compress lengthy news content into a concise format.
#
# **Model Selected:**
# sshleifer/distilbart-cnn-12-6
#
# **Justification for Model Selection:**
# DistilBART is optimized for speed and efficiency, making it well-suited for rapid summarization tasks.
#
# **Result:**
# The system generated compact summaries that retained the essential information from the original articles.
#
# **Further improvement**
# - Question Answering models can be added
# - Text to voice models can be integrate for reading out the summary
# - And many more ....
